# %% [markdown]
# <a href="https://colab.research.google.com/github/puckerm/test_project/blob/main/Assignment_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
from matplotlib import pyplot as plt
import graphviz

### Tensorflow 2.0 ###
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import Input
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow.keras import metrics
from tensorflow.keras import regularizers
from tensorflow.keras import utils

# %%
# 아래 있는 model의 plot을 보고 그대로 CNN 모델을 구현하시오
# Hint : 각 layer에서 사용된 이름이 좌측에 적혀있습니다.
#        오른쪽의 2개는 순서대로 input과 ouput의 shape입니다.
# 모델을 구현한 후에 model.summary() 를 써서 맨 아래 있는 것처럼 출력되도록 하시오.

# %%
model = Sequential([layers.Input(shape=(128, 128, 1)),
                    
                    layers.Conv2D(filters=16, kernel_size=3, strides=1, padding='same'),
                    layers.MaxPooling2D(pool_size=2),
                    
                    layers.Conv2D(filters=32, kernel_size=3, strides=1, padding='same'),
                    layers.MaxPooling2D(pool_size=2),
                    
                    layers.Conv2D(filters=64, kernel_size=3, strides=1, padding='same'),
                    layers.MaxPooling2D(pool_size=2),
                    
                    layers.Flatten(),
                    layers.Dense(128, activation='relu'),
                    layers.Dropout(0.2),
                    layers.Dense(5, activation='relu')])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_3 (Conv2D)           (None, 128, 128, 16)      160
#
#  max_pooling2d_3 (MaxPooling  (None, 64, 64, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 16384)             0
#
#  dense_2 (Dense)             (None, 128)               2097280
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 5)                 645
#
# ...
# Total params: 2,121,221
# Trainable params: 2,121,221
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True)
